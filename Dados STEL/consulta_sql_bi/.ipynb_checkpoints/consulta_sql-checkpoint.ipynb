# %% [markdown]
# ### Conexão Banco SQL server

# %%
import pyodbc
import pandas as pd
import copy

server = 'd64v38i'
username = 'user_sa_licenciamento_leitura_ext'
password = '1qEr3@ext'
database = 'sa_licenciamento'

connection_string = 'DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password

# Conectar ao banco de dados
connection = pyodbc.connect(connection_string)

# Consulta SQL
def sql_query(query):
    return pd.read_sql(query, connection)

# %% [markdown]
# ### Importando as tabelas - sql_incra, assunto, endereço

# %%
# SQL_INCRA
df_sql_incra = sql_query('SELECT * FROM dbo.prata_sql_incra')
df_sql_incra.info()
# Out:
# C:\Users\d850398\AppData\Local\Temp\ipykernel_20168\1644747194.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, connection)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1709328 entries, 0 to 1709327
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_prata_sql_incra    int64
#  1   id_prata_assunto      int64
#  2   sistema               object
#  3   processo              object
#  4   protocolo             object
#  5   codigoAssuntoObra     object
#  6   sql_incra             object
#  7   tipoSql_incra         object
#  8   origem_carga          object
#  9   origem_sql_incra      object
#  10  dtcarga               datetime64[ns]
#  11  origem_tipoSql_incra  object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 156.5+ MB

# %%
# Assunto
df_assunto = sql_query('SELECT * FROM dbo.prata_assunto')
df_assunto.info()
# Out:
# C:\Users\d850398\AppData\Local\Temp\ipykernel_20168\1644747194.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, connection)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1561215 entries, 0 to 1561214
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   id_prata_assunto         1561215 non-null  int64
#  1   id_prata_processo        1561215 non-null  int64
#  2   sistema                  1561215 non-null  object
#  3   processo                 1554964 non-null  object
#  4   protocolo                213873 non-null   object
#  5   codigoAssuntoObra        1561215 non-null  object
#  6   dtInclusaoAssunto        1553856 non-null  object
#  7   assuntoCod               1476368 non-null  object
#  8   assunto                  1561215 non-null  object
#  9   aditivo                  1527140 non-null  object
#  10  tipoRequerimento         179842 non-null   object
#  11  situacaoAssunto          1561212 non-null  object
#  12  numeroAlvara             1450540 non-null  object
#  13  dtEmissaoAlvara          836828 non-null   object
#  14  statusAlvara             132587 non-null   object
#  15  dtcarga                  1561215 non-null  datetime64[ns]
#  16  origem_situacaoAssunto   1561212 non-null  object
#  17  origem_assuntoCod        1476368 non-null  object
#  18  origem_assunto           1561215 non-null  object
#  19  origem_aditivo           1527140 non-null  object
#  20  origem_tipoRequerimento  179842 non-null   object
#  21  origem_numeroAlvara      1450540 non-null  object
#  22  origem_dtEmissaoAlvara   836828 non-null   object
#  23  origem_statusAlvara      132587 non-null   object
#  24  familiaASsunto           1241685 non-null  object
#  25  assuntoFormatado         1561215 non-null  object
#  26  assuntoPrincipal         1561215 non-null  object
#  27  assuntoGrupo             15509 non-null    object
#  28  instancia                96092 non-null    object
#  29  tipoAditivo              1348688 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(27)
# memory usage: 357.3+ MB

# %%
# Endereço
df_endereco = sql_query('SELECT * FROM dbo.prata_endereco')
df_endereco.info()
# Out:
# C:\Users\d850398\AppData\Local\Temp\ipykernel_20168\1644747194.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(query, connection)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1941761 entries, 0 to 1941760
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_prata_endereco     int64
#  1   id_prata_assunto      int64
#  2   sistema               object
#  3   processo              object
#  4   protocolo             object
#  5   codigoAssuntoObra     object
#  6   codlog                object
#  7   logradouro            object
#  8   numero                object
#  9   bairro                object
#  10  cep                   object
#  11  subprefeitura         object
#  12  distrito              object
#  13  origem_carga          object
#  14  origem_codlog         object
#  15  origem_logradouro     object
#  16  origem_numero         object
#  17  origem_bairro         object
#  18  origem_cep            object
#  19  origem_subprefeitura  object
#  20  origem_distrito       object
#  21  dtcarga               datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(19)
# memory usage: 325.9+ MB

# %% [markdown]
# ### Consulta SQL

# %%
# Colocar lista de SQLs no documento consulta_sql na mesma pasta do arquivo
with open('filtro_sql.txt', 'r') as sqls_file:
    sql_list = list(map(lambda x: x[:-1], sqls_file.readlines()))

sql_list[:5]
# Out:
# ['082.439.0036-5',
#  '082.439.0035-7',
#  '200.014.0013-2',
#  '200.014.0014-0',
#  '200.014.0003-5']

# %%
# Consulta SQL
consulta_sql = df_sql_incra[df_sql_incra['sql_incra'].isin(sql_list)]
print(consulta_sql.shape)
consulta_sql = consulta_sql.dropna(subset='processo')
print(consulta_sql.shape)
# Out:
# (250, 12)
# (242, 12)

# %%
# Left join com processos on processo
df_merge_sql = pd.merge(consulta_sql, df_assunto, how='left', on='processo')
df_merge_sql = pd.merge(df_merge_sql, df_endereco, how='left', on='processo')
df_merge_sql.head()
# Out:
#    id_prata_sql_incra  id_prata_assunto_x      sistema_x             processo  \
# 0             1423440             1066959  AprovaDigital  1020.2021/0008732-0
# 1             1423440             1066959  AprovaDigital  1020.2021/0008732-0
# 2             1427563             1071536  AprovaDigital  1020.2021/0018254-3
# 3             1427563             1071536  AprovaDigital  1020.2021/0018254-3
# 4             1432847             1077537  AprovaDigital  1020.2022/0012199-6
#
#        protocolo_x       codigoAssuntoObra_x       sql_incra tipoSql_incra  \
# 0   3905-21-SP-DEM  60c927a974815b000abb4252  082.412.0046-3           SQL
# 1   3905-21-SP-DEM  60c927a974815b000abb4252  082.412.0046-3           SQL
# 2   8482-21-SP-ALV  619d1176ebe55c000abfcdab  200.042.0010-1           SQL
# 3   8482-21-SP-ALV  619d1176ebe55c000abfcdab  200.042.0010-1           SQL
# 4  14483-22-SP-ALV  629e3128c64d3700093d3d01  082.410.0093-6           SQL
#
#                          origem_carga_x origem_sql_incra  ... distrito  \
# 0  last_version.dados_terreno.campo_sql   082.412.0046-3  ...     None
# 1  last_version.dados_terreno.campo_sql   082.412.0046-3  ...     None
# 2  last_version.dados_terreno.campo_sql      20004200101  ...     None
# 3  last_version.dados_terreno.campo_sql      20004200101  ...     None
# 4  last_version.dados_terreno.campo_sql      08241000936  ...     None
#
#                                origem_carga_y  origem_codlog  \
# 0  last_version.dados_terreno.nome_logradouro        17420-3
# 1  last_version.dados_terreno.nome_logradouro        17420-3
# 2  last_version.dados_terreno.nome_logradouro         039373
# 3  last_version.dados_terreno.nome_logradouro         039373
# 4  last_version.dados_terreno.nome_logradouro         039373
#
#        origem_logradouro origem_numero origem_bairro origem_cep  \
# 0  Rua Santa Rosa Junior           283       Butantã  05579-010
# 1  Rua Santa Rosa Junior           283       Butantã  05579-010
# 2            RUA CAMARGO           431       BUTANTÃ   05510050
# 3            RUA CAMARGO           431       BUTANTÃ   05510050
# 4              R CAMARGO           267       Butantã   05510050
#
#   origem_subprefeitura origem_distrito             dtcarga
# 0                 None            None 2023-10-31 17:40:00
# 1                 None            None 2023-11-01 11:53:00
# 2                 None            None 2023-10-31 17:40:00
# 3                 None            None 2023-11-01 11:53:00
# 4                 None            None 2023-10-31 17:40:00
#
# [5 rows x 62 columns]

# %%
df_merge_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 62 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_prata_sql_incra       1226 non-null   int64
#  1   id_prata_assunto_x       1226 non-null   int64
#  2   sistema_x                1226 non-null   object
#  3   processo                 1226 non-null   object
#  4   protocolo_x              90 non-null     object
#  5   codigoAssuntoObra_x      1226 non-null   object
#  6   sql_incra                1226 non-null   object
#  7   tipoSql_incra            1226 non-null   object
#  8   origem_carga_x           1160 non-null   object
#  9   origem_sql_incra         1226 non-null   object
#  10  dtcarga_x                1226 non-null   datetime64[ns]
#  11  origem_tipoSql_incra     1176 non-null   object
#  12  id_prata_assunto_y       1226 non-null   int64
#  13  id_prata_processo        1226 non-null   int64
#  14  sistema_y                1226 non-null   object
#  15  protocolo_y              90 non-null     object
#  16  codigoAssuntoObra_y      1226 non-null   object
#  17  dtInclusaoAssunto        1226 non-null   object
#  18  assuntoCod               1184 non-null   object
#  19  assunto                  1226 non-null   object
#  20  aditivo                  1202 non-null   object
#  21  tipoRequerimento         66 non-null     object
#  22  situacaoAssunto          1226 non-null   object
#  23  numeroAlvara             1195 non-null   object
#  24  dtEmissaoAlvara          341 non-null    object
#  25  statusAlvara             61 non-null     object
#  26  dtcarga_y                1226 non-null   datetime64[ns]
#  27  origem_situacaoAssunto   1226 non-null   object
#  28  origem_assuntoCod        1184 non-null   object
#  29  origem_assunto           1226 non-null   object
#  30  origem_aditivo           1202 non-null   object
#  31  origem_tipoRequerimento  66 non-null     object
#  32  origem_numeroAlvara      1195 non-null   object
#  33  origem_dtEmissaoAlvara   341 non-null    object
#  34  origem_statusAlvara      61 non-null     object
#  35  familiaASsunto           1088 non-null   object
#  36  assuntoFormatado         1226 non-null   object
#  37  assuntoPrincipal         1226 non-null   object
#  38  assuntoGrupo             12 non-null     object
#  39  instancia                42 non-null     object
#  40  tipoAditivo              1136 non-null   object
#  41  id_prata_endereco        1219 non-null   float64
#  42  id_prata_assunto         1219 non-null   float64
#  43  sistema                  1219 non-null   object
#  44  protocolo                84 non-null     object
#  45  codigoAssuntoObra        1219 non-null   object
#  46  codlog                   1157 non-null   object
#  47  logradouro               1219 non-null   object
#  48  numero                   1215 non-null   object
#  49  bairro                   1153 non-null   object
#  50  cep                      1191 non-null   object
#  51  subprefeitura            18 non-null     object
#  52  distrito                 64 non-null     object
#  53  origem_carga_y           1155 non-null   object
#  54  origem_codlog            1157 non-null   object
#  55  origem_logradouro        1219 non-null   object
#  56  origem_numero            1215 non-null   object
#  57  origem_bairro            1153 non-null   object
#  58  origem_cep               1191 non-null   object
#  59  origem_subprefeitura     18 non-null     object
#  60  origem_distrito          64 non-null     object
#  61  dtcarga                  1219 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), float64(2), int64(4), object(53)
# memory usage: 594.0+ KB

# %%
with open('filtro_assunto.txt', 'r', encoding='utf-8') as txt_file:
    assunto_list = txt_file.readlines()
    assunto_list = [i for i in assunto_list if i[0] != '#']
    assunto_list = [i[:-1] for i in assunto_list]

assunto_list
# Out:
# ['Apostilamento de Alvará de Desmembramento de Gleba',
#  'Reconsideração de Despacho do Alvará de Desmembramento',
#  'Alvará de Remembramento e Desmembramento de Gleba',
#  'Alvará de Desmembramento de Lote',
#  'Alvará de Desmembramento de Gleba',
#  'Desmembramento Para Secção Em Zeis',
#  'Alvará Para Desmembramento/reparcelamento',
#  'Alvará de Desmembramento + Alvará de Aprovação de Edificação Nova (plano Integrado)',
#  'Reconsideração de Despacho de Alvará de Remembramento e Desmembramento de Gleba',
#  'Alvará Para Desmembramento/ Remembramento/ Reparcelamento',
#  'Apostilamento do Alvará de Desmembramento',
#  'Revalidação de Alvará de Desmembramento de Gleba',
#  'Projeto Modificativo do Alvará de Desmembramento',
#  'Alvará de Desmembramento',
#  'Reconsideração de Despacho de Alvará de Desmembramento de Gleba',
#  'Revalidação do Alvará de Desmembramento',
#  'Projeto Modificativo de Alvará de Desmembramento de Gleba',
#  'Alvará de Desmembramento + Alvará de Aprovação e Execução de Edificação Nova (plano Integrado)',
#  'Apostilamento de Alvará de Remembramento e Desmembramento de Gleba',
#  'Certidao de Diretrizes Para Desmembramento',
#  'Reconsideração de Despacho de Certidao de Diretrizes Para Desmembramento',
#  'Apostilamento de Certidao de Diretrizes Para Desmembramento',
#  '',
#  '',
#  'Apostilamento de Alvará de Desdobro de Lote',
#  'Reconsideração de Despacho de Alvará de Desdobro de Lote',
#  'Reconsideração de Despacho de Alvará de Remembramento e Desdobro de Lote',
#  'Revalidação de Alvará de Remembramento e Desdobro de Lote',
#  'Revalidação de Alvará de Desdobro de Lote',
#  'Alvará de Desdobro de Lote',
#  'Alvará de Remembramento e Desdobro de Lote',
#  'Apostilamento de Alvará de Remembramento e Desdobro de Lote',
#  'Projeto Modificativo de Alvará de Desdobro de Lote',
#  'Projeto Modificativo de Alvará de Remembramento e Desdobro de Lote',
#  '',
#  '',
#  'Alvará de Remembramento e Desmembramento de Gleba',
#  'Reconsideração de Despacho de Alvará de Remembramento e Desdobro de Lote',
#  'Reconsideração de Despacho de Alvará de Remembramento de Lote',
#  'Reconsideração de Despacho de Alvará de Remembramento e Desmembramento de Gleba',
#  'Alvará Para Desmembramento/ Remembramento/ Reparcelamento',
#  'Revalidação de Alvará de Remembramento e Desdobro de Lote',
#  'Apostilamento de Alvará de Remembramento de Lote',
#  'Alvará de Remembramento de Lote',
#  'Projeto Modificativo de Alvará de Remembramento de Lote',
#  'Alvará de Remembramento e Desdobro de Lote',
#  'Apostilamento de Alvará de Remembramento e Desdobro de Lote',
#  'Projeto Modificativo de Alvará de Remembramento e Desdobro de Lote',
#  'Apostilamento de Alvará de Remembramento e Desmembramento de Gleba',
#  '',
#  '',
#  'Apostilamento do Alvará de Reparcelamento',
#  'Alvará Para Desmembramento/reparcelamento',
#  'Alvará de Reparcelamento de Lote',
#  'Alvará Para Desmembramento/ Remembramento/ Reparcelamento',
#  'Certidao de Diretriz de Reparcelamento',
#  'Reconsideração de Despacho do Alvará de Reparcelamento',
#  'Alvará de Reparcelamento',
#  '',
#  '',
#  'Projeto Modificativo de Alvará de Loteamento',
#  'Apostilamento de Certidao de Diretrizes Para Loteamento',
#  'Alvará de Loteamento',
#  'Alvará de Loteamento + Alvará de Aprovação e Execução de Edificação Nova (plano Integrado)',
#  'Alvará de Loteamento + Alvará de Aprovação de Edificação Nova (plano Integrado)',
#  'Autorizacao Para Execução Das Obras de Loteamento',
#  'Auto de Regularização de Loteamento',
#  'Reconsideração de Despacho de Certidao de Diretrizes Para Loteamento',
#  'Certidao de Diretrizes Para Loteamento',
#  'Apostilamento de Alvará de Loteamento',
#  'Apostilamento de Auto de Regularização de Loteamento',
#  'Alvará de Loteamento Para Fins de Registro',
#  'Reconsideração de Despacho de Auto de Regularização de Loteamento',
#  'Apostilamento de Alvará de Loteamento Para Fins de Registro',
#  'Apostilamento de Autorização Para Execução Das Obras de Loteamento',
#  'Reconsideração de Despacho de Alvará de Loteamento',
#  '',
#  '',
#  'Alvará de Aprovação de Reforma (HIS e HMP)',
#  'Alvará de Aprovação de Reforma (exceto HIS/ HMP)',
#  'Alvará de Aprovação de Reforma',
#  'Alvará de Aprovação de Edificação Nova (HIS/ HMP)',
#  'Apostilamento de Alvará de Aprovação de Reforma',
#  'Projeto Modificativo de Alvará de Aprovação de Reforma',
#  'Revalidação de Alvará de Aprovação de Edificação Nova',
#  'Alvará de Aprovação de Edificação Nova (HIS/ HMP) - Programa Pode Entrar',
#  'Alvará de Loteamento + Alvará de Aprovação de Edificação Nova (plano Integrado)',
#  'Alvará de Aprovação de Requalificação',
#  'Alvará de Desmembramento + Alvará de Aprovação de Edificação Nova (plano Integrado)',
#  'Alvará de Aprovação de Reforma (HIS/ HMP)',
#  'Reconsideração de Despacho de Alvará de Aprovação de Requalificação',
#  'Projeto Modificativo de Alvará de Aprovação de Edificação Nova',
#  'Alvará de Aprovação de Edificação Nova (Pode Entrar)',
#  'Alvará de Aprovação de Edificação Nova (exceto HIS/ HMP)',
#  'Apostilamento de Alvará de Aprovação de Edificação Nova',
#  'Reconsideração de Despacho de Alvará de Aprovação de Reforma',
#  'Apostilamento de Alvará de Aprovação de Requalificação',
#  'Alvará de Aprovação de Edificação Nova',
#  'Revalidação de Alvará de Aprovação de Reforma',
#  'Alvará de Aprovação de Reforma (Pode Entrar)',
#  'Reconsideração de Despacho de Alvará de Aprovação de Edificação Nova',
#  '',
#  '',
#  'Projeto Modificativo de Alvará de Execução de Reforma',
#  'Apostilamento de Alvará de Aprovação e de Execução de Requalificação',
#  'Alvará de Execução de Requalificação',
#  'Reconsideração de Despacho de Alvará de Execução de Edificação Nova',
#  'Reconsideração de Despacho de Alvará de Aprovação e de Execução de Requalificação',
#  'Revalidação de Alvará de Execução de Edificação Nova',
#  'Alvará de Execução de Edificação Nova',
#  'Alvará de Execução de Reforma (exceto HIS/ HMP)',
#  'Projeto Modificativo de Alvará de Aprovação e de Execução de Requalificação',
#  'Apostilamento de Alvará de Execução de Reconstrução',
#  'Apostilamento de Alvará de Execução de Edificação Nova',
#  'Apostilamento de Alvará de Execução de Reforma',
#  'Alvará de Execução de Reconstrução',
#  'Alvará de Execução de Edificação Nova (HIS/ HMP)',
#  'Alvará de Execução de Reforma (HIS e HMP)',
#  'Reconsideração de Despacho de Alvará de Execução de Reconstrução',
#  'Reconsideração de Despacho de Alvará de Execução de Reforma',
#  'Revalidação de Alvará de Execução de Reforma',
#  'Alvará de Execução de Reforma (HIS/ HMP)',
#  'Alvará de Execução de Edificação Nova (HIS/ HMP) - Programa Pode Entrar',
#  'Alvará de Execução de Edificação Nova (Pode Entrar)',
#  'Projeto Modificativo de Alvará de Execução de Edificação Nova',
#  'Alvará de Execução de Reforma',
#  'Reconsideração de Despacho de Alvará de Execução de Requalificação',
#  'Apostilamento de Alvará de Execução de Requalificação',
#  'Alvará de Execução de Edificação Nova (exceto HIS/ HMP)',
#  '',
#  '',
#  'Revalidação de Alvará de Aprovação e Execução de Reforma',
#  'Alvará de Aprovação e Execução de Reforma (Pode Entrar)',
#  'Alvará de Aprovação e Execução Para Residência Unifamiliar',
#  'Reconsideração Despacho de Alvará de Aprovação e Execução de Edificação Nova',
#  'Alvará de Aprovação e Execução de Edificação Nova',
#  'Revalidação de Alvará Aprovação e Execução Para Residencias Unifamiliares',
#  'Projeto Modificativo de Alvará de Aprovação e Execução de Edificação Nova (HIS / HMP)',
#  'Revalidação de Alvará de Aprovação e Execução de Edificação Nova',
#  'Alvará de Aprovação e Execução de Requalificação',
#  'Alvará de Aprovação e Execução de Edificação Nova (HIS/ HMP) - Programa Pode Entrar',
#  'Reconsideração de Despacho de Alvará de Aprovação e Execução de Reforma',
#  'Projeto Modificativo de Alvará de Aprovação e Execução de Reforma (exceto HIS / HMP)',
#  'Alvará de Aprovação e Execução de Reforma',
#  'Alvará de Aprovação e Execução de Reforma (HIS/ HMP)',
#  'Projeto Modificativo de Alvará de Aprovação e Execução Para Residencias Unifamiliares',
#  'Alvará de Aprovação e Execução de Edificação Nova (HIS/ HMP)',
#  'Reconsideração de Despacho de Alvará de Aprovação e Execução Para Residencias Unifamiliares',
#  'Projeto Modificativo de Alvará de Aprovação e Execução de Edificação Nova',
#  'Projeto Modificativo de Alvará de Aprovação e Execução de Reforma',
#  'Alvará de Aprovação e Execução de Reforma (exceto HIS e HMP)',
#  'Alvará de Aprovação e Execução de Edificação Nova (Pode Entrar)',
#  'Alvará de Aprovação e Execução ou Modificativo de Edificação Nova (HIS/ HMP) - Programa Pode Entrar',
#  'Projeto Modificativo de Alvará de Aprovação e Execução de Reforma (HIS / HMP)',
#  'Alvará de Aprovação e Execução Para Residencias Unifamiliares',
#  'Apostilamento de Alvará de Aprovação e Execução Para Residencias Unifamiliares',
#  'Apostilamento de Alvará de Aprovação e Execução de Edificação Nova',
#  'Projeto Modificativo de Alvará de Aprovação e Execução de Edificação Nova (exceto HIS / HMP)',
#  'Apostilamento de Alvará de Aprovação e Execução de Reforma',
#  'Alvará de Aprovação e Execução de Edificação Nova (exceto HIS/ HMP)',
#  'Alvará de Aprovação e Execução de Edificação Nova - Processo Declaratório',
#  'Alvará de Desmembramento + Alvará de Aprovação e Execução de Edificação Nova (plano Integrado)',
#  'Alvará de Loteamento + Alvará de Aprovação e Execução de Edificação Nova (plano Integrado']

# %%
# Filtrando por assunto
assunto_filtrado_sql = df_merge_sql[df_merge_sql['assuntoFormatado'].isin(assunto_list)]

# %%
# Tabela final - saída para excel
consulta_final_sql = assunto_filtrado_sql[['sql_incra', 'processo', 'assuntoFormatado', 'situacaoAssunto', 'dtInclusaoAssunto', 'dtEmissaoAlvara', 'numeroAlvara', 'codlog', 'logradouro', 'numero', 'sistema_x']]
consulta_final_sql.columns = ['sql_incra', 'processo', 'assunto', 'situacao', 'data_inclusao_assunto', 'data_emissao_alvara', 'numero_alvara', 'codlog', 'logradouro', 'numero', 'sistema_origem']
consulta_final_sql = consulta_final_sql.sort_values(by=['sql_incra', 'data_inclusao_assunto'], ascending=[True, False])
consulta_final_sql = consulta_final_sql.drop_duplicates(subset=['processo'])

# %% [markdown]
# ### Consulta por endereço

# %% [markdown]
# #### Busca por codlog

# %%
df_codlog = df_endereco.dropna(subset=['numero', 'codlog', 'processo'])
df_codlog.loc[:,'processo'] = df_codlog['processo'].replace('', None)

# %%
# Pradronização codlogs da base BI
def codlog_nomask(codlog):
    codlog = codlog.replace('-', '')  # Tirando o hifen do digito verificador
    codlog = codlog.zfill(6)  # Todos com 6 dígitos 

    return codlog
    
df_codlog.loc[:,'codlog_pdr'] = df_codlog['codlog'].apply(codlog_nomask)
df_codlog.head(10)
# Out:
# C:\Users\d850398\AppData\Local\Temp\ipykernel_20168\3313208894.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_codlog.loc[:,'codlog_pdr'] = df_codlog['codlog'].apply(codlog_nomask)
#     id_prata_endereco  id_prata_assunto sistema             processo  \
# 13            1453562           1407655    SLCe  0000.2014/0290089-5
# 14            1453563           1393922    SLCe  0000.2013/0286509-5
# 20            1453569           1383137    SLCe  0000.2012/0293701-9
# 22            1453571           1391204    SLCe  0000.2013/0268040-0
# 23            1453572           1399616    SLCe  0000.2014/0067527-4
# 24            1453573           1409561    SLCe  0000.2014/0324523-8
# 25            1453574           1403022    SLCe  0000.2014/0189711-4
# 26            1453575           1386484    SLCe  0000.2013/0133501-7
# 36            1453585           1397517    SLCe  0000.2014/0059902-0
# 37            1453586           1386852    SLCe  0000.2013/0141087-6
#
#    protocolo                     codigoAssuntoObra   codlog  \
# 13  29037-14  39E2A8DE-594E-E411-91B9-EEB04C01FAF4  16758-4
# 14  28414-13  684299AA-6769-E311-94B6-005056BC4B88  45657-8
# 20    783-12  9EFD8B26-E80B-E211-962F-005056BC4B84  72952-3
# 22  18444-13  48DC1E3A-1D1A-E311-B47B-005056BC4B84  14112-7
# 23  27952-14  771DF867-E047-E411-91B9-005056BC4B84  07445-4
# 24  31945-14  D73B46DD-B163-E411-9391-005056BC4B88  09030-1
# 25  18186-14  E526BA78-E705-E411-9165-00505693585A  02804-5
# 26  28664-13  AAAABE30-FD6B-E311-8DC5-0050568F5ED3  71465-8
# 36   4135-14  A26930BB-9F95-E311-A368-00505693585A  16422-4
# 37   9268-13  BA73296D-7AB9-E211-BC1E-005056BC4B88  17759-8
#
#                               logradouro numero bairro  ... origem_carga  \
# 13                    R   QUIPA UMARIZAL  00143   None  ...         None
# 14               R   COROLAMPIO TRILLAS   00009   None  ...         None
# 20       R CAPITAO ANTONIO BUENO RANGEL      81   None  ...         None
# 22             R   JOSE NOBREGA BARBOSA   00124   None  ...         None
# 23                    R   HUGO CAROTINI   00123   None  ...         None
# 24                   R   AGUANAMBI 1100A  01100   None  ...         None
# 25          R   DOS BANQUEIROS LT 4 QD Y  00000   None  ...         None
# 26  R   DOMINGOS SIMOES LT 12 QD 40 VL S  00000   None  ...         None
# 36                          R   PLATINA   00360   None  ...         None
# 37        R   BARAO SANTA EULALIA AP 201  00300   None  ...         None
#
#    origem_codlog                     origem_logradouro origem_numero  \
# 13       16758-4                    R   QUIPA|UMARIZAL         00143
# 14       45657-8               R   COROLAMPIO TRILLAS|         00009
# 20       72952-3       R CAPITAO ANTONIO BUENO RANGEL|            81
# 22       14112-7             R   JOSE NOBREGA BARBOSA|         00124
# 23       07445-4                    R   HUGO CAROTINI|         00123
# 24       09030-1                   R   AGUANAMBI|1100A         01100
# 25       02804-5          R   DOS BANQUEIROS|LT 4 QD Y         00000
# 26       71465-8  R   DOMINGOS SIMOES|LT 12 QD 40 VL S         00000
# 36       16422-4                          R   PLATINA|         00360
# 37       17759-8        R   BARAO SANTA EULALIA|AP 201         00300
#
#    origem_bairro origem_cep origem_subprefeitura    origem_distrito  \
# 13          None  05756-440                 None        CAMPO LIMPO
# 14          None  08471-260                 None  CIDADE TIRADENTES
# 20          None  05158-440                 None       SAO DOMINGOS
# 22          None  02336-090                 None           TUCURUVI
# 23          None  05532-020                 None            BUTANTA
# 24          None  08461-140                 None         GUAIANASES
# 25          None  03918-050                 None          SAPOPEMBA
# 26          None  05630-010                 None         VILA SONIA
# 36          None  03308-010                 None            TATUAPE
# 37          None  05685-090                 None            MORUMBI
#
#                dtcarga codlog_pdr
# 13 2023-10-27 14:58:00     167584
# 14 2023-10-27 14:58:00     456578
# 20 2023-10-27 14:58:00     729523
# 22 2023-10-27 14:58:00     141127
# 23 2023-10-27 14:58:00     074454
# 24 2023-10-27 14:58:00     090301
# 25 2023-10-27 14:58:00     028045
# 26 2023-10-27 14:58:00     714658
# 36 2023-10-27 14:58:00     164224
# 37 2023-10-27 14:58:00     177598
#
# [10 rows x 23 columns]

# %%
# Padronização dos números
def not_a_num(string):
    for n, i in enumerate(string):
        if not i.isnumeric():
            return n
    return n
    
def num_cleaner(num):
    num = str(num) + 'a'
    return num[:not_a_num(num)]

def make_int(num):
    return int(num)

df_codlog.loc[:,'numero_pdr'] = df_codlog['numero'].apply(num_cleaner)
df_codlog.loc[:,'numero_pdr'] = df_codlog['numero_pdr'].replace('', 0)
df_codlog.loc[:,'numero_pdr'] = df_codlog['numero_pdr'].apply(make_int)
df_codlog.head()
# Out:
# C:\Users\d850398\AppData\Local\Temp\ipykernel_20168\1975681881.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_codlog.loc[:,'numero_pdr'] = df_codlog['numero'].apply(num_cleaner)
#     id_prata_endereco  id_prata_assunto sistema             processo  \
# 13            1453562           1407655    SLCe  0000.2014/0290089-5
# 14            1453563           1393922    SLCe  0000.2013/0286509-5
# 20            1453569           1383137    SLCe  0000.2012/0293701-9
# 22            1453571           1391204    SLCe  0000.2013/0268040-0
# 23            1453572           1399616    SLCe  0000.2014/0067527-4
#
#    protocolo                     codigoAssuntoObra   codlog  \
# 13  29037-14  39E2A8DE-594E-E411-91B9-EEB04C01FAF4  16758-4
# 14  28414-13  684299AA-6769-E311-94B6-005056BC4B88  45657-8
# 20    783-12  9EFD8B26-E80B-E211-962F-005056BC4B84  72952-3
# 22  18444-13  48DC1E3A-1D1A-E311-B47B-005056BC4B84  14112-7
# 23  27952-14  771DF867-E047-E411-91B9-005056BC4B84  07445-4
#
#                          logradouro numero bairro  ... origem_codlog  \
# 13               R   QUIPA UMARIZAL  00143   None  ...       16758-4
# 14          R   COROLAMPIO TRILLAS   00009   None  ...       45657-8
# 20  R CAPITAO ANTONIO BUENO RANGEL      81   None  ...       72952-3
# 22        R   JOSE NOBREGA BARBOSA   00124   None  ...       14112-7
# 23               R   HUGO CAROTINI   00123   None  ...       07445-4
#
#                   origem_logradouro origem_numero origem_bairro origem_cep  \
# 13               R   QUIPA|UMARIZAL         00143          None  05756-440
# 14          R   COROLAMPIO TRILLAS|         00009          None  08471-260
# 20  R CAPITAO ANTONIO BUENO RANGEL|            81          None  05158-440
# 22        R   JOSE NOBREGA BARBOSA|         00124          None  02336-090
# 23               R   HUGO CAROTINI|         00123          None  05532-020
#
#    origem_subprefeitura    origem_distrito             dtcarga codlog_pdr  \
# 13                 None        CAMPO LIMPO 2023-10-27 14:58:00     167584
# 14                 None  CIDADE TIRADENTES 2023-10-27 14:58:00     456578
# 20                 None       SAO DOMINGOS 2023-10-27 14:58:00     729523
# 22                 None           TUCURUVI 2023-10-27 14:58:00     141127
# 23                 None            BUTANTA 2023-10-27 14:58:00     074454
#
#    numero_pdr
# 13        143
# 14          9
# 20         81
# 22        124
# 23        123
#
# [5 rows x 24 columns]

# %%
# Lendo codlogs e numeros
with open('filtro_endereco.txt', 'r') as txt_file:
    endereco_list = txt_file.readlines()

endereco_list = [i[:-1] for i in endereco_list]
codlog_num = [(i.split(',')[0], int(i.split(',')[2]), int(i.split(',')[3])) for i in endereco_list]

codlog_num
# Out:
# [('046663', 406, 434),
#  ('125024', 590, 810),
#  ('194557', 0, 213),
#  ('198170', 417, 560),
#  ('196614', 80, 120),
#  ('001007', 410, 446),
#  ('008559', 1030, 1051),
#  ('039373', 149, 571),
#  ('153362', 15, 35),
#  ('187836', 50, 70),
#  ('078093', 12, 32),
#  ('165808', 0, 164),
#  ('169137', 136, 224),
#  ('174203', 273, 29)]

# %%
df_container = [df_codlog[(df_codlog['codlog'] == i[0]) & (df_codlog['numero_pdr'] > i[1]) & (df_codlog['numero_pdr'] < i[2])] for i in codlog_num]

#consulta_codlog = df_codlog[(df_codlog['codlog'] == '009997') & (df_codlog['numero_pdr'] > 1000) & (df_codlog['numero_pdr'] < 1500)]
consulta_codlog = pd.concat(df_container)  
consulta_codlog
# Out:
#          id_prata_endereco  id_prata_assunto  sistema             processo  \
# 1348685            4277614            803235  Sisacoe  0000.2018/0021452-5
# 1408323            4337252            862103  Sisacoe  0000.2019/0047300-0
# 1621548            4550477           1268529  Sisacoe  0000.1994/0104976-9
# 1626529            4555458            364057  Sisacoe  0000.2003/1032012-3
# 1626835            4555764           1067774  Sisacoe  0000.2018/0021452-5
# ...                    ...               ...      ...                  ...
# 1338132            4267061           1001136  Sisacoe  0000.1994/0081086-5
# 1383126            4312055            568913  Sisacoe  0000.2006/0149148-0
# 1666827            4595756           1091204  Sisacoe  0000.1994/0081021-0
# 1754193            4683122            985232  Sisacoe  0000.1994/0081021-0
# 1917995            4846924            876088  Sisacoe  0000.2004/0023149-9
#
#         protocolo codigoAssuntoObra  codlog                       logradouro  \
# 1348685      None           1729448  125024        AV   MAGALHAES DE CASTRO
# 1408323      None           1709411  125024        AV   MAGALHAES DE CASTRO
# 1621548      None            296855  125024        AV   MAGALHAES DE CASTRO
# 1626529      None            626764  125024        AV   MAGALHAES DE CASTRO
# 1626835      None           1648163  125024        AV   MAGALHAES DE CASTRO
# ...           ...               ...     ...                              ...
# 1338132      None             51338  169137  R   REACAO LOTE 23 DA QUADRA 09
# 1383126      None            906879  169137                      R   REACAO
# 1666827      None            864176  169137                      R   REACAO
# 1754193      None            307679  169137                      R   REACAO
# 1917995      None            699683  169137                      R   REACAO
#
#         numero                bairro  ... origem_codlog  \
# 1348685  600.-               BUTANTA  ...        125024
# 1408323  600.-               BUTANTA  ...        125024
# 1621548  691.-               BUTANTA  ...        125024
# 1626529  691.-               BUTANTA  ...        125024
# 1626835  600.-               BUTANTA  ...        125024
# ...        ...                   ...  ...           ...
# 1338132  212.-              BUTANTA.  ...        169137
# 1383126  00217                  None  ...        169137
# 1666827  00217                  None  ...        169137
# 1754193  00217                  None  ...        169137
# 1917995  00186  BUTANTA               ...        169137
#
#                 origem_logradouro origem_numero         origem_bairro  \
# 1348685                                   600.-               BUTANTA
# 1408323                                   600.-               BUTANTA
# 1621548                                   691.-               BUTANTA
# 1626529                                   691.-               BUTANTA
# 1626835                                   600.-               BUTANTA
# ...                           ...           ...                   ...
# 1338132      LOTE 23 DA QUADRA 09         212.-              BUTANTA.
# 1383126                                   00217                  None
# 1666827                                   00217                  None
# 1754193                                   00217                  None
# 1917995                                   00186  BUTANTA
#
#         origem_cep origem_subprefeitura origem_distrito             dtcarga  \
# 1348685    5502000                 None            None 2023-11-01 16:03:00
# 1408323    5502000                 None            None 2023-11-01 16:03:00
# 1621548    5502001                 None            None 2023-11-01 16:03:00
# 1626529    5502001                 None            None 2023-11-01 16:03:00
# 1626835    5502000                 None            None 2023-11-01 16:03:00
# ...            ...                  ...             ...                 ...
# 1338132    5510030                 None            None 2023-11-01 16:03:00
# 1383126       None                 None            None 2023-11-01 16:03:00
# 1666827       None                 None            None 2023-11-01 16:03:00
# 1754193       None                 None            None 2023-11-01 16:03:00
# 1917995    5510030                 None            None 2023-11-01 16:03:00
#
#         codlog_pdr numero_pdr
# 1348685     125024        600
# 1408323     125024        600
# 1621548     125024        691
# 1626529     125024        691
# 1626835     125024        600
# ...            ...        ...
# 1338132     169137        212
# 1383126     169137        217
# 1666827     169137        217
# 1754193     169137        217
# 1917995     169137        186
#
# [129 rows x 24 columns]

# %%
# left join processos on processo
df_merge_codlog = pd.merge(consulta_codlog, pd.merge(df_assunto, df_sql_incra, how='left', on='processo'), how='left', on='processo')
df_merge_codlog.head()

# %%
# Filtrando por assunto
assunto_filtrado_codlog = df_merge_codlog[df_merge_codlog['assuntoFormatado'].isin(assunto_list)]

# %%
consulta_final_codlog = assunto_filtrado_codlog[['codlog_pdr', 'logradouro', 'numero_pdr', 'processo', 'assuntoFormatado', 'situacaoAssunto', 'dtInclusaoAssunto', 'dtEmissaoAlvara', 'numeroAlvara' , 'sistema_x']]
consulta_final_codlog.columns = ['codlog', 'logradouro', 'numero', 'processo', 'assunto', 'situacao', 'data_inclusao_assunto', 'data_emissao_alvara', 'numero_alvara', 'sistema_origem']
consulta_final_codlog = consulta_final_codlog.sort_values(by=['codlog', 'data_inclusao_assunto'], ascending=[True, False])
consulta_final_codlog = consulta_final_codlog.drop_duplicates(subset=['processo'])

# %%
# Gerando EXCEL
with pd.ExcelWriter('consulta_sql_endereco.xlsx') as writer:
    consulta_final_sql.to_excel(writer, sheet_name='consulta_sql', index=False)
    consulta_final_codlog.to_excel(writer, sheet_name='consulta_codlog', index=False)
