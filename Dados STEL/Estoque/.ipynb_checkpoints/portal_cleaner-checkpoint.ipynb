# %%
import os 
import pandas as pd

# %%
dados = pd.read_excel('raw_data\portal.xlsx')
dados.head(10)
# Out:
#   Data de autuação   Número do Processo  \
# 0       07/01/2020  6068.2020/0000001-5
# 1       07/01/2020  6068.2020/0000001-5
# 2       07/01/2020  6068.2020/0000001-5
# 3       09/01/2020  6068.2020/0000002-3
# 4       09/01/2020  6068.2020/0000002-3
# 5       09/01/2020  6068.2020/0000002-3
# 6       09/01/2020  6068.2020/0000003-1
# 7       09/01/2020  6068.2020/0000003-1
# 8       13/01/2020  6068.2020/0000004-0
# 9       13/01/2020  6068.2020/0000004-0
#
#                                           Assunto Localização do Processo  \
# 0  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019        \SEL\GTEC\GTEC-1
# 1  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019               \SEL\GTEC
# 2  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019        \SEL\GTEC\GTEC-1
# 3  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019        \SEL\GTEC\GTEC-1
# 4  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019        \SEL\GTEC\GTEC-1
# 5  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019               \SEL\GTEC
# 6  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019        \SEL\GTEC\GTEC-2
# 7  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019        \SEL\GTEC\GTEC-2
# 8  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019        \SEL\GTEC\GTEC-1
# 9  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019        \SEL\GTEC\GTEC-1
#
#        Status
# 0  Indeferida
# 1  Indeferida
# 2  Indeferida
# 3  Indeferida
# 4  Indeferida
# 5    Deferida
# 6  Indeferida
# 7  Indeferida
# 8  Indeferida
# 9  Indeferida

# %%
dados.columns = ["dt_autuacao", "n_processos","assunto","unidade","status"]
dados.head(10)
# Out:
#   dt_autuacao          n_processos  \
# 0  07/01/2020  6068.2020/0000001-5
# 1  07/01/2020  6068.2020/0000001-5
# 2  07/01/2020  6068.2020/0000001-5
# 3  09/01/2020  6068.2020/0000002-3
# 4  09/01/2020  6068.2020/0000002-3
# 5  09/01/2020  6068.2020/0000002-3
# 6  09/01/2020  6068.2020/0000003-1
# 7  09/01/2020  6068.2020/0000003-1
# 8  13/01/2020  6068.2020/0000004-0
# 9  13/01/2020  6068.2020/0000004-0
#
#                                           assunto           unidade  \
# 0  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
# 1  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019         \SEL\GTEC
# 2  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
# 3  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
# 4  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
# 5  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019         \SEL\GTEC
# 6  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2
# 7  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2
# 8  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
# 9  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
#
#        status
# 0  Indeferida
# 1  Indeferida
# 2  Indeferida
# 3  Indeferida
# 4  Indeferida
# 5    Deferida
# 6  Indeferida
# 7  Indeferida
# 8  Indeferida
# 9  Indeferida

# %%
contagem = dados['unidade'].value_counts()
print(contagem)
# Out:
# unidade
# \SEL\GTEC                   39536
# \SEL\CASE\DDU\Análise       15291
# \SEL\GTEC\GTEC-3\Análise    15220
# \SEL\GTEC\GTEC-1\Análise    11730
# \SEL\GTEC\GTEC-2\Análise     9704
# \SEL\GTEC\GTEC-2             6596
# \SEL\GTEC\GTEC-3             5721
# \SEL\GTEC\GTEC-1             3936
# \SEL\CASE\DDU                1202
# Name: count, dtype: int64

# %%
dados_sem_duplicados = dados.drop_duplicates(subset=['n_processos'])

# %%
contagem1 = dados_sem_duplicados['unidade'].value_counts()
print(contagem1)
# Out:
# unidade
# \SEL\GTEC                   19507
# \SEL\CASE\DDU\Análise       15291
# \SEL\GTEC\GTEC-3\Análise     7409
# \SEL\GTEC\GTEC-1\Análise     5730
# \SEL\GTEC\GTEC-2\Análise     4654
# \SEL\GTEC\GTEC-2             3045
# \SEL\GTEC\GTEC-3             2617
# \SEL\GTEC\GTEC-1             1669
# \SEL\CASE\DDU                1202
# Name: count, dtype: int64

# %%
dados_sem_duplicados.head(10)
# Out:
#    dt_autuacao          n_processos  \
# 0   07/01/2020  6068.2020/0000001-5
# 3   09/01/2020  6068.2020/0000002-3
# 6   09/01/2020  6068.2020/0000003-1
# 8   13/01/2020  6068.2020/0000004-0
# 11  15/01/2020  6068.2020/0000005-8
# 14  15/01/2020  6068.2020/0000006-6
# 16  15/01/2020  6068.2020/0000007-4
# 18  15/01/2020  6068.2020/0000008-2
# 21  15/01/2020  6068.2020/0000009-0
# 23  15/01/2020  6068.2020/0000010-4
#
#                                            assunto                   unidade  \
# 0   CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019          \SEL\GTEC\GTEC-1
# 3   CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019          \SEL\GTEC\GTEC-1
# 6   CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019          \SEL\GTEC\GTEC-2
# 8   CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019          \SEL\GTEC\GTEC-1
# 11  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1\Análise
# 14  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019          \SEL\GTEC\GTEC-2
# 16  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019          \SEL\GTEC\GTEC-3
# 18  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019          \SEL\GTEC\GTEC-1
# 21  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019          \SEL\GTEC\GTEC-1
# 23  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019          \SEL\GTEC\GTEC-1
#
#         status
# 0   Indeferida
# 3   Indeferida
# 6   Indeferida
# 8   Indeferida
# 11  Indeferida
# 14    Deferida
# 16    Deferida
# 18  Indeferida
# 21    Deferida
# 23  Indeferida

# %%
# Suponha que temos um DataFrame chamado 'dados' e queremos agrupar por uma coluna
coluna = 'unidade'  # Substitua pelo nome correto da coluna
value_counts = dados[coluna].value_counts()  # Conta os valores únicos na coluna

# %%
grupos = dados.groupby(coluna)

# %%
tabelas = {}

# %%
# Itera sobre cada grupo e armazena em um dicionário ou outro contêiner
for nome, grupo in grupos:
    tabelas[nome] = grupo
    # Para mostrar as primeiras linhas de cada tabela
    print(f"Tabela para '{nome}':")
    print(grupo.head(), "\n")
# Out:
# Tabela para '\SEL\CASE\DDU':
#       dt_autuacao          n_processos        assunto        unidade   status
# 50014  14/10/2021  1020.2021/0015455-8  FICHA TÉCNICA  \SEL\CASE\DDU  Emitida
# 50015  14/10/2021  1020.2021/0015456-6  FICHA TÉCNICA  \SEL\CASE\DDU  Emitida
# 50016  14/10/2021  1020.2021/0015457-4  FICHA TÉCNICA  \SEL\CASE\DDU  Emitida
# 50192  14/10/2021  1020.2021/0015608-9  FICHA TÉCNICA  \SEL\CASE\DDU  Emitida
# 50211  14/10/2021  1020.2021/0015618-6  FICHA TÉCNICA  \SEL\CASE\DDU  Emitida
#
# Tabela para '\SEL\CASE\DDU\Análise':
#       dt_autuacao          n_processos        assunto                unidade  \
# 58308  19/03/2022  1020.2022/0004085-6  FICHA TÉCNICA  \SEL\CASE\DDU\Análise
# 58311  19/03/2022  1020.2022/0004088-0  FICHA TÉCNICA  \SEL\CASE\DDU\Análise
# 58425  21/03/2022  1020.2022/0004203-4  FICHA TÉCNICA  \SEL\CASE\DDU\Análise
# 58490  21/03/2022  1020.2022/0004237-9  FICHA TÉCNICA  \SEL\CASE\DDU\Análise
# 59025  25/03/2022  1020.2022/0004602-1  FICHA TÉCNICA  \SEL\CASE\DDU\Análise
#
#         status
# 58308  Emitida
# 58311  Emitida
# 58425  Emitida
# 58490  Emitida
# 59025  Emitida
#
# Tabela para '\SEL\GTEC':
#    dt_autuacao          n_processos  \
# 1   07/01/2020  6068.2020/0000001-5
# 5   09/01/2020  6068.2020/0000002-3
# 10  13/01/2020  6068.2020/0000004-0
# 19  15/01/2020  6068.2020/0000008-2
# 25  15/01/2020  6068.2020/0000010-4
#
#                                            assunto    unidade      status
# 1   CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC  Indeferida
# 5   CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC    Deferida
# 10  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC  Indeferida
# 19  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC    Deferida
# 25  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC    Deferida
#
# Tabela para '\SEL\GTEC\GTEC-1':
#   dt_autuacao          n_processos  \
# 0  07/01/2020  6068.2020/0000001-5
# 2  07/01/2020  6068.2020/0000001-5
# 3  09/01/2020  6068.2020/0000002-3
# 4  09/01/2020  6068.2020/0000002-3
# 8  13/01/2020  6068.2020/0000004-0
#
#                                           assunto           unidade  \
# 0  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
# 2  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
# 3  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
# 4  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
# 8  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1
#
#        status
# 0  Indeferida
# 2  Indeferida
# 3  Indeferida
# 4  Indeferida
# 8  Indeferida
#
# Tabela para '\SEL\GTEC\GTEC-1\Análise':
#    dt_autuacao          n_processos  \
# 11  15/01/2020  6068.2020/0000005-8
# 47  16/01/2020  6068.2020/0000019-8
# 73  18/01/2020  1020.2020/0000010-9
# 74  18/01/2020  1020.2020/0000010-9
# 86  18/01/2020  1020.2020/0000016-8
#
#                                            assunto                   unidade  \
# 11  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1\Análise
# 47  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1\Análise
# 73  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1\Análise
# 74  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1\Análise
# 86  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-1\Análise
#
#         status
# 11  Indeferida
# 47  Indeferida
# 73  Indeferida
# 74  Indeferida
# 86  Em Análise
#
# Tabela para '\SEL\GTEC\GTEC-2':
#    dt_autuacao          n_processos  \
# 6   09/01/2020  6068.2020/0000003-1
# 7   09/01/2020  6068.2020/0000003-1
# 14  15/01/2020  6068.2020/0000006-6
# 15  15/01/2020  6068.2020/0000006-6
# 80  18/01/2020  1020.2020/0000013-3
#
#                                            assunto           unidade  \
# 6   CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2
# 7   CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2
# 14  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2
# 15  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2
# 80  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2
#
#         status
# 6   Indeferida
# 7   Indeferida
# 14    Deferida
# 15    Deferida
# 80  Indeferida
#
# Tabela para '\SEL\GTEC\GTEC-2\Análise':
#     dt_autuacao          n_processos  \
# 101  21/01/2020  1020.2020/0000022-2
# 114  21/01/2020  1020.2020/0000027-3
# 126  22/01/2020  1020.2020/0000034-6
# 127  22/01/2020  1020.2020/0000034-6
# 128  22/01/2020  1020.2020/0000034-6
#
#                                             assunto                   unidade  \
# 101  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2\Análise
# 114  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2\Análise
# 126  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2\Análise
# 127  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2\Análise
# 128  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-2\Análise
#
#          status
# 101  Indeferida
# 114  Em Análise
# 126  Em Análise
# 127  Indeferida
# 128  Indeferida
#
# Tabela para '\SEL\GTEC\GTEC-3':
#    dt_autuacao          n_processos  \
# 16  15/01/2020  6068.2020/0000007-4
# 17  15/01/2020  6068.2020/0000007-4
# 29  15/01/2020  6068.2020/0000012-0
# 30  15/01/2020  6068.2020/0000012-0
# 31  16/01/2020  6068.2020/0000013-9
#
#                                            assunto           unidade  \
# 16  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-3
# 17  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-3
# 29  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-3
# 30  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-3
# 31  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-3
#
#         status
# 16    Deferida
# 17    Deferida
# 29    Deferida
# 30    Deferida
# 31  Indeferida
#
# Tabela para '\SEL\GTEC\GTEC-3\Análise':
#    dt_autuacao          n_processos  \
# 43  16/01/2020  6068.2020/0000018-0
# 44  16/01/2020  6068.2020/0000018-0
# 57  17/01/2020  1020.2020/0000003-6
# 58  17/01/2020  1020.2020/0000003-6
# 63  17/01/2020  1020.2020/0000005-2
#
#                                            assunto                   unidade  \
# 43  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-3\Análise
# 44  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-3\Análise
# 57  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-3\Análise
# 58  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-3\Análise
# 63  CERTIFICADO DE REGULARIZAÇÃO - Lei 17.202/2019  \SEL\GTEC\GTEC-3\Análise
#
#         status
# 43  Em Análise
# 44  Em Análise
# 57  Indeferida
# 58  Indeferida
# 63  Em Análise

# %%
pasta = 'Portal_Licenciamento'

# %%
# Criar a pasta se não existir
if not os.path.exists(pasta):
    os.makedirs(pasta)
    print(f"Pasta '{pasta}' criada.")
# Out:
# Pasta 'Portal_Licenciamento' criada.

# %%
# Salvar cada grupo como um arquivo CSV na pasta especificada
for nome, grupo in grupos:
    arquivo_csv = os.path.join(pasta, f'portal_{nome}.csv')  # Caminho completo do arquivo
    grupo.to_csv(arquivo_csv, index=False)  # Salva sem o índice
    print(f"Salvou '{arquivo_csv}' para a palavra '{nome}'")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[40], line 4
#       2 for nome, grupo in grupos:
#       3     arquivo_csv = os.path.join(pasta, f'{nome}.csv')  # Caminho completo do arquivo
# ----> 4     grupo.to_csv(arquivo_csv, index=False)  # Salva sem o índice
#       5     print(f"Salvou '{arquivo_csv}' para a palavra '{nome}'")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:247, in CSVFormatter.save(self)
#     243 """
#     244 Create the writer & save.
#     245 """
#     246 # apply compression and byte/text conversion
# --> 247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#     250     encoding=self.encoding,
#     251     errors=self.errors,
#     252     compression=self.compression,
#     253     storage_options=self.storage_options,
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
#     266     self._save()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:739, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     737 # Only for write methods
#     738 if "r" not in mode and is_path:
# --> 739     check_parent_directory(str(handle))
#     741 if compression:
#     742     if compression != "zstd":
#     743         # compression libraries do not like an explicit text-mode
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:604, in check_parent_directory(path)
#     602 parent = Path(path).parent
#     603 if not parent.is_dir():
# --> 604     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '\SEL\CASE'
