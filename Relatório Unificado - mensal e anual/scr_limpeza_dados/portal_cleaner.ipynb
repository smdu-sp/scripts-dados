# %%
import pandas as pd
import os
import glob
from datetime import datetime

# %%
# Absolute path para o diretório atual
dir_atual = os.getcwd()
# Absolute path para o diretório irmão onde os arquivos serão criados
dir_raw_data = os.path.abspath(os.path.join(dir_atual,'..', 'raw_data'))
dir_cleaned_data = os.path.abspath(os.path.join(dir_atual, '..','cleaned_data'))

# %%
print (dir_atual)
print (dir_raw_data)
print (dir_cleaned_data)
# Out:
# C:\Users\d850398\Documents\GitHub\relatorio_unificado\limpeza_dados
# C:\Users\d850398\Documents\GitHub\relatorio_unificado\raw_data
# C:\Users\d850398\Documents\GitHub\relatorio_unificado\cleaned_data

# %% [markdown]
# ## Unificando dados do portal

# %%
nome_arquivo_raiz = "portal_card-produtividade"

# %%
padrao_nome_arquivo = os.path.join(dir_raw_data, nome_arquivo_raiz + "*.xlsx")
padrao_nome_arquivo
# Out:
# 'C:\\Users\\d850398\\Documents\\GitHub\\relatorio_unificado\\raw_data\\portal_card-produtividade*.xlsx'

# %%
nomes_arquivos = glob.glob(padrao_nome_arquivo)
nomes_arquivos
# Out:
# ['C:\\Users\\d850398\\Documents\\GitHub\\relatorio_unificado\\raw_data\\portal_card-produtividade-unidade-usuario-tarefa-2023-12-05T15_15_00.291Z.xlsx',
#  'C:\\Users\\d850398\\Documents\\GitHub\\relatorio_unificado\\raw_data\\portal_card-produtividade-unidade-usuario-tarefa-2023-12-05T15_15_06.313Z.xlsx',
#  'C:\\Users\\d850398\\Documents\\GitHub\\relatorio_unificado\\raw_data\\portal_card-produtividade-unidade-usuario-tarefa-2023-12-05T15_15_12.884Z.xlsx',
#  'C:\\Users\\d850398\\Documents\\GitHub\\relatorio_unificado\\raw_data\\portal_card-produtividade-unidade-usuario-tarefa-2023-12-05T15_15_18.914Z.xlsx',
#  'C:\\Users\\d850398\\Documents\\GitHub\\relatorio_unificado\\raw_data\\portal_card-produtividade-unidade-usuario-tarefa-2023-12-05T15_16_12.716Z.xlsx',
#  'C:\\Users\\d850398\\Documents\\GitHub\\relatorio_unificado\\raw_data\\portal_card-produtividade-unidade-usuario-tarefa-2023-12-05T15_16_18.924Z.xlsx',
#  'C:\\Users\\d850398\\Documents\\GitHub\\relatorio_unificado\\raw_data\\portal_card-produtividade-unidade-usuario-tarefa-2023-12-05T15_16_26.188Z.xlsx']

# %%
dfs = []

# %%
for nome_arquivo in nomes_arquivos:
    df = pd.read_excel(nome_arquivo)
    dfs.append(df)

# %%
soma = 0 

for i in dfs:
    soma += i.shape[0]
    print(i.shape[0])

print(soma)
# Out:
# 1518
# 3678
# 10600
# 6056
# 13755
# 4596
# 11130
# 51333

# %%
df_final = pd.concat(dfs, ignore_index=True)

# %%
df_final = df_final.drop(['UsuarioExecutorTarefa','ResultadoTarefa'], axis=1)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51333 entries, 0 to 51332
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Protocolo                   51333 non-null  object
#  1   Processo                    51333 non-null  object
#  2   TipoDocumentoEmitidoTarefa  38095 non-null  object
#  3   DataUltimaAtualizacao       51333 non-null  object
# dtypes: object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Criando Planilha de Despachos

# %%
df_final
# Out:
#         Protocolo             Processo       TipoDocumentoEmitidoTarefa  \
# 0       1007/2021  1020.2020/0000125-3  Despacho de Indeferimento Comum
# 1      10096/2023  1020.2022/0004097-0    Despacho de Deferimento Comum
# 2      10118/2021  1020.2021/0002133-7  Despacho de Indeferimento Comum
# 3      10152/2022  1020.2021/0011041-0                         Anulação
# 4      10152/2022  1020.2021/0011041-0                              NaN
# ...           ...                  ...                              ...
# 51328   9952/2022  1020.2021/0001135-8        Comunique-se complementar
# 51329   9952/2022  1020.2021/0001135-8     Cota Proposta de Deferimento
# 51330   9952/2022  1020.2021/0001135-8     Cota Proposta de Deferimento
# 51331    996/2023  1020.2020/0004143-3     Cota Proposta de Deferimento
# 51332   9966/2020  1020.2020/0000860-6                     Comunique-se
#
#       DataUltimaAtualizacao
# 0                03/05/2021
# 1                07/06/2023
# 2                12/03/2021
# 3                10/06/2022
# 4                28/07/2022
# ...                     ...
# 51328            08/05/2023
# 51329            05/10/2023
# 51330            25/08/2023
# 51331            16/01/2023
# 51332            11/03/2021
#
# [51333 rows x 4 columns]

# %%
desp_filter = ['Despacho de Indeferimento Comum','Despacho de Deferimento Comum']
portal_despachos = df_final.query("TipoDocumentoEmitidoTarefa.isin(@desp_filter)")
portal_despachos.head(10)
# Out:
#      Protocolo             Processo       TipoDocumentoEmitidoTarefa  \
# 0    1007/2021  1020.2020/0000125-3  Despacho de Indeferimento Comum
# 1   10096/2023  1020.2022/0004097-0    Despacho de Deferimento Comum
# 2   10118/2021  1020.2021/0002133-7  Despacho de Indeferimento Comum
# 5   10390/2021  1020.2021/0002132-9  Despacho de Indeferimento Comum
# 6   10410/2021  1020.2021/0001961-8  Despacho de Indeferimento Comum
# 7    1044/2022  1020.2021/0009438-5    Despacho de Deferimento Comum
# 8   10650/2021  1020.2020/0001343-0  Despacho de Indeferimento Comum
# 9   10845/2022  1020.2020/0015718-0    Despacho de Deferimento Comum
# 10  11017/2022  1020.2020/0011846-0    Despacho de Deferimento Comum
# 11   1120/2022  1020.2020/0014468-2    Despacho de Deferimento Comum
#
#    DataUltimaAtualizacao
# 0             03/05/2021
# 1             07/06/2023
# 2             12/03/2021
# 5             12/03/2021
# 6             24/06/2021
# 7             06/06/2022
# 8             10/02/2022
# 9             07/06/2023
# 10            30/05/2022
# 11            29/03/2022

# %%
portal_despachos = portal_despachos.rename(columns={'Protocolo': 'n_protocolo', 'Processo': 'n_processo', 'TipoDocumentoEmitidoTarefa':'despacho', 'DataUltimaAtualizacao':'data_despacho'})
portal_despachos.head(10)
# Out:
#    n_protocolo           n_processo                         despacho  \
# 0    1007/2021  1020.2020/0000125-3  Despacho de Indeferimento Comum
# 1   10096/2023  1020.2022/0004097-0    Despacho de Deferimento Comum
# 2   10118/2021  1020.2021/0002133-7  Despacho de Indeferimento Comum
# 5   10390/2021  1020.2021/0002132-9  Despacho de Indeferimento Comum
# 6   10410/2021  1020.2021/0001961-8  Despacho de Indeferimento Comum
# 7    1044/2022  1020.2021/0009438-5    Despacho de Deferimento Comum
# 8   10650/2021  1020.2020/0001343-0  Despacho de Indeferimento Comum
# 9   10845/2022  1020.2020/0015718-0    Despacho de Deferimento Comum
# 10  11017/2022  1020.2020/0011846-0    Despacho de Deferimento Comum
# 11   1120/2022  1020.2020/0014468-2    Despacho de Deferimento Comum
#
#    data_despacho
# 0     03/05/2021
# 1     07/06/2023
# 2     12/03/2021
# 5     12/03/2021
# 6     24/06/2021
# 7     06/06/2022
# 8     10/02/2022
# 9     07/06/2023
# 10    30/05/2022
# 11    29/03/2022

# %%
portal_despachos['coord_despacho'] = 'GTEC'
portal_despachos.head(10)
# Out:
#    n_protocolo           n_processo                         despacho  \
# 0    1007/2021  1020.2020/0000125-3  Despacho de Indeferimento Comum
# 1   10096/2023  1020.2022/0004097-0    Despacho de Deferimento Comum
# 2   10118/2021  1020.2021/0002133-7  Despacho de Indeferimento Comum
# 5   10390/2021  1020.2021/0002132-9  Despacho de Indeferimento Comum
# 6   10410/2021  1020.2021/0001961-8  Despacho de Indeferimento Comum
# 7    1044/2022  1020.2021/0009438-5    Despacho de Deferimento Comum
# 8   10650/2021  1020.2020/0001343-0  Despacho de Indeferimento Comum
# 9   10845/2022  1020.2020/0015718-0    Despacho de Deferimento Comum
# 10  11017/2022  1020.2020/0011846-0    Despacho de Deferimento Comum
# 11   1120/2022  1020.2020/0014468-2    Despacho de Deferimento Comum
#
#    data_despacho coord_despacho
# 0     03/05/2021           GTEC
# 1     07/06/2023           GTEC
# 2     12/03/2021           GTEC
# 5     12/03/2021           GTEC
# 6     24/06/2021           GTEC
# 7     06/06/2022           GTEC
# 8     10/02/2022           GTEC
# 9     07/06/2023           GTEC
# 10    30/05/2022           GTEC
# 11    29/03/2022           GTEC

# %%
today = datetime.now().strftime('%Y.%m.%d')

# %%
portal_despachos['data_extracao'] = today
portal_despachos.head(10)
# Out:
#    n_protocolo           n_processo                         despacho  \
# 0    1007/2021  1020.2020/0000125-3  Despacho de Indeferimento Comum
# 1   10096/2023  1020.2022/0004097-0    Despacho de Deferimento Comum
# 2   10118/2021  1020.2021/0002133-7  Despacho de Indeferimento Comum
# 5   10390/2021  1020.2021/0002132-9  Despacho de Indeferimento Comum
# 6   10410/2021  1020.2021/0001961-8  Despacho de Indeferimento Comum
# 7    1044/2022  1020.2021/0009438-5    Despacho de Deferimento Comum
# 8   10650/2021  1020.2020/0001343-0  Despacho de Indeferimento Comum
# 9   10845/2022  1020.2020/0015718-0    Despacho de Deferimento Comum
# 10  11017/2022  1020.2020/0011846-0    Despacho de Deferimento Comum
# 11   1120/2022  1020.2020/0014468-2    Despacho de Deferimento Comum
#
#    data_despacho coord_despacho data_extracao
# 0     03/05/2021           GTEC    2023.12.05
# 1     07/06/2023           GTEC    2023.12.05
# 2     12/03/2021           GTEC    2023.12.05
# 5     12/03/2021           GTEC    2023.12.05
# 6     24/06/2021           GTEC    2023.12.05
# 7     06/06/2022           GTEC    2023.12.05
# 8     10/02/2022           GTEC    2023.12.05
# 9     07/06/2023           GTEC    2023.12.05
# 10    30/05/2022           GTEC    2023.12.05
# 11    29/03/2022           GTEC    2023.12.05

# %%
portal_despachos.shape
# Out:
# (8136, 6)

# %% [markdown]
# ## Criando Planilha de Comuniqueses

# %%
df_final.head(10)
# Out:
#     Protocolo             Processo       TipoDocumentoEmitidoTarefa  \
# 0   1007/2021  1020.2020/0000125-3  Despacho de Indeferimento Comum
# 1  10096/2023  1020.2022/0004097-0    Despacho de Deferimento Comum
# 2  10118/2021  1020.2021/0002133-7  Despacho de Indeferimento Comum
# 3  10152/2022  1020.2021/0011041-0                         Anulação
# 4  10152/2022  1020.2021/0011041-0                              NaN
# 5  10390/2021  1020.2021/0002132-9  Despacho de Indeferimento Comum
# 6  10410/2021  1020.2021/0001961-8  Despacho de Indeferimento Comum
# 7   1044/2022  1020.2021/0009438-5    Despacho de Deferimento Comum
# 8  10650/2021  1020.2020/0001343-0  Despacho de Indeferimento Comum
# 9  10845/2022  1020.2020/0015718-0    Despacho de Deferimento Comum
#
#   DataUltimaAtualizacao
# 0            03/05/2021
# 1            07/06/2023
# 2            12/03/2021
# 3            10/06/2022
# 4            28/07/2022
# 5            12/03/2021
# 6            24/06/2021
# 7            06/06/2022
# 8            10/02/2022
# 9            07/06/2023

# %%
df_final.TipoDocumentoEmitidoTarefa.unique()
# Out:
# array(['Despacho de Indeferimento Comum', 'Despacho de Deferimento Comum',
#        'Anulação', nan, 'Cota Encaminhamento Livre',
#        'Cota Proposta de Deferimento', 'Cota Proposta de Indeferimento',
#        'Comunique-se complementar', 'Comunique-se', 'NEC'], dtype=object)

# %%
comun_filter = ['Comunique-se','Comunique-se complementar']
portal_comuniqueses = df_final.query("TipoDocumentoEmitidoTarefa.isin(@comun_filter)")
portal_comuniqueses.head(10)
# Out:
#        Protocolo             Processo TipoDocumentoEmitidoTarefa  \
# 5196  10500/2022  1020.2020/0004263-4  Comunique-se complementar
# 5197  10500/2022  1020.2020/0004263-4               Comunique-se
# 5198  10555/2023  1020.2020/0012380-4               Comunique-se
# 5199  11162/2022  1020.2022/0004278-6               Comunique-se
# 5200  11817/2020  1020.2020/0008542-2               Comunique-se
# 5201  11817/2020  1020.2020/0008542-2  Comunique-se complementar
# 5202  11817/2020  1020.2020/0008542-2  Comunique-se complementar
# 5204  12678/2021  1020.2021/0002916-8               Comunique-se
# 5205  12691/2022  1020.2022/0003759-6               Comunique-se
# 5206  12691/2022  1020.2022/0003759-6  Comunique-se complementar
#
#      DataUltimaAtualizacao
# 5196            17/08/2023
# 5197            27/06/2023
# 5198            11/10/2023
# 5199            06/11/2023
# 5200            01/06/2023
# 5201            04/08/2023
# 5202            28/09/2023
# 5204            28/07/2023
# 5205            07/12/2022
# 5206            11/01/2023

# %%
portal_comuniqueses = portal_comuniqueses.drop(['TipoDocumentoEmitidoTarefa'], axis=1)
portal_comuniqueses.head(10)
# Out:
#        Protocolo             Processo DataUltimaAtualizacao
# 5196  10500/2022  1020.2020/0004263-4            17/08/2023
# 5197  10500/2022  1020.2020/0004263-4            27/06/2023
# 5198  10555/2023  1020.2020/0012380-4            11/10/2023
# 5199  11162/2022  1020.2022/0004278-6            06/11/2023
# 5200  11817/2020  1020.2020/0008542-2            01/06/2023
# 5201  11817/2020  1020.2020/0008542-2            04/08/2023
# 5202  11817/2020  1020.2020/0008542-2            28/09/2023
# 5204  12678/2021  1020.2021/0002916-8            28/07/2023
# 5205  12691/2022  1020.2022/0003759-6            07/12/2022
# 5206  12691/2022  1020.2022/0003759-6            11/01/2023

# %%
portal_comuniqueses = portal_comuniqueses.rename(columns={'Protocolo': 'n_protocolo', 'Processo': 'n_processo','DataUltimaAtualizacao':'data_comuniquese'})
portal_comuniqueses.head(10)
# Out:
#      n_protocolo           n_processo data_comuniquese
# 5196  10500/2022  1020.2020/0004263-4       17/08/2023
# 5197  10500/2022  1020.2020/0004263-4       27/06/2023
# 5198  10555/2023  1020.2020/0012380-4       11/10/2023
# 5199  11162/2022  1020.2022/0004278-6       06/11/2023
# 5200  11817/2020  1020.2020/0008542-2       01/06/2023
# 5201  11817/2020  1020.2020/0008542-2       04/08/2023
# 5202  11817/2020  1020.2020/0008542-2       28/09/2023
# 5204  12678/2021  1020.2021/0002916-8       28/07/2023
# 5205  12691/2022  1020.2022/0003759-6       07/12/2022
# 5206  12691/2022  1020.2022/0003759-6       11/01/2023

# %%
portal_comuniqueses['coord_comuniquese'] = 'GTEC'
portal_comuniqueses.head(10)
# Out:
#      n_protocolo           n_processo data_comuniquese coord_comuniquese
# 5196  10500/2022  1020.2020/0004263-4       17/08/2023              GTEC
# 5197  10500/2022  1020.2020/0004263-4       27/06/2023              GTEC
# 5198  10555/2023  1020.2020/0012380-4       11/10/2023              GTEC
# 5199  11162/2022  1020.2022/0004278-6       06/11/2023              GTEC
# 5200  11817/2020  1020.2020/0008542-2       01/06/2023              GTEC
# 5201  11817/2020  1020.2020/0008542-2       04/08/2023              GTEC
# 5202  11817/2020  1020.2020/0008542-2       28/09/2023              GTEC
# 5204  12678/2021  1020.2021/0002916-8       28/07/2023              GTEC
# 5205  12691/2022  1020.2022/0003759-6       07/12/2022              GTEC
# 5206  12691/2022  1020.2022/0003759-6       11/01/2023              GTEC

# %%
portal_comuniqueses['data_extracao'] = today
portal_comuniqueses.head(10)
# Out:
#      n_protocolo           n_processo data_comuniquese coord_comuniquese  \
# 5196  10500/2022  1020.2020/0004263-4       17/08/2023              GTEC
# 5197  10500/2022  1020.2020/0004263-4       27/06/2023              GTEC
# 5198  10555/2023  1020.2020/0012380-4       11/10/2023              GTEC
# 5199  11162/2022  1020.2022/0004278-6       06/11/2023              GTEC
# 5200  11817/2020  1020.2020/0008542-2       01/06/2023              GTEC
# 5201  11817/2020  1020.2020/0008542-2       04/08/2023              GTEC
# 5202  11817/2020  1020.2020/0008542-2       28/09/2023              GTEC
# 5204  12678/2021  1020.2021/0002916-8       28/07/2023              GTEC
# 5205  12691/2022  1020.2022/0003759-6       07/12/2022              GTEC
# 5206  12691/2022  1020.2022/0003759-6       11/01/2023              GTEC
#
#      data_extracao
# 5196    2023.12.05
# 5197    2023.12.05
# 5198    2023.12.05
# 5199    2023.12.05
# 5200    2023.12.05
# 5201    2023.12.05
# 5202    2023.12.05
# 5204    2023.12.05
# 5205    2023.12.05
# 5206    2023.12.05

# %% [markdown]
# ## Salvando Arquivos

# %%
portal_despachos.head(10)
# Out:
#    n_protocolo           n_processo                         despacho  \
# 0    1007/2021  1020.2020/0000125-3  Despacho de Indeferimento Comum
# 1   10096/2023  1020.2022/0004097-0    Despacho de Deferimento Comum
# 2   10118/2021  1020.2021/0002133-7  Despacho de Indeferimento Comum
# 5   10390/2021  1020.2021/0002132-9  Despacho de Indeferimento Comum
# 6   10410/2021  1020.2021/0001961-8  Despacho de Indeferimento Comum
# 7    1044/2022  1020.2021/0009438-5    Despacho de Deferimento Comum
# 8   10650/2021  1020.2020/0001343-0  Despacho de Indeferimento Comum
# 9   10845/2022  1020.2020/0015718-0    Despacho de Deferimento Comum
# 10  11017/2022  1020.2020/0011846-0    Despacho de Deferimento Comum
# 11   1120/2022  1020.2020/0014468-2    Despacho de Deferimento Comum
#
#    data_despacho coord_despacho data_extracao
# 0     03/05/2021           GTEC    2023.12.05
# 1     07/06/2023           GTEC    2023.12.05
# 2     12/03/2021           GTEC    2023.12.05
# 5     12/03/2021           GTEC    2023.12.05
# 6     24/06/2021           GTEC    2023.12.05
# 7     06/06/2022           GTEC    2023.12.05
# 8     10/02/2022           GTEC    2023.12.05
# 9     07/06/2023           GTEC    2023.12.05
# 10    30/05/2022           GTEC    2023.12.05
# 11    29/03/2022           GTEC    2023.12.05

# %%
portal_comuniqueses.head(10)
# Out:
#      n_protocolo           n_processo data_comuniquese coord_comuniquese  \
# 5196  10500/2022  1020.2020/0004263-4       17/08/2023              GTEC
# 5197  10500/2022  1020.2020/0004263-4       27/06/2023              GTEC
# 5198  10555/2023  1020.2020/0012380-4       11/10/2023              GTEC
# 5199  11162/2022  1020.2022/0004278-6       06/11/2023              GTEC
# 5200  11817/2020  1020.2020/0008542-2       01/06/2023              GTEC
# 5201  11817/2020  1020.2020/0008542-2       04/08/2023              GTEC
# 5202  11817/2020  1020.2020/0008542-2       28/09/2023              GTEC
# 5204  12678/2021  1020.2021/0002916-8       28/07/2023              GTEC
# 5205  12691/2022  1020.2022/0003759-6       07/12/2022              GTEC
# 5206  12691/2022  1020.2022/0003759-6       11/01/2023              GTEC
#
#      data_extracao
# 5196    2023.12.05
# 5197    2023.12.05
# 5198    2023.12.05
# 5199    2023.12.05
# 5200    2023.12.05
# 5201    2023.12.05
# 5202    2023.12.05
# 5204    2023.12.05
# 5205    2023.12.05
# 5206    2023.12.05

# %%
portal_despachos.to_csv(f'{dir_cleaned_data}/portal_despachos.csv', index=False, sep=';')

# %%
portal_comuniqueses.to_csv(f'{dir_cleaned_data}/portal_comuniqueses.csv', index=False, sep=';')
